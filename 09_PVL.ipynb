# %% [markdown]
# ## PVL
# This notebook focuses on using the PVL library (https://github.com/planetarypy/pvl) to work with image labels.
#
# The link includes installation instructions, basically: `pip install pvl`.  Once installed, we are off to the races.

# %%
import pvl

# %% [markdown]
# The PVL library accesses the data set and extracts the PVL formatted header into a Python dictionary.  The python diction, like the PVL, is nested.  Therefore, we define a helper function that will recursively search a dictionary for a key.
#
# Note: This function returns the **first** instance of the key.

# %%
def find_in_dict(obj, key):
    """
    Recursively find an entry in a dictionary

    Parameters
    ----------
    obj : dict
          The dictionary to search
    key : str
          The key to find in the dictionary

    Returns
    -------
    item : obj
           The value from the dictionary
    """
    if key in obj:
        return obj[key]
    for k, v in obj.items():
        if isinstance(v,dict):
            item = find_in_dict(v, key)
            if item is not None:
                return item

# %% [markdown]
# The PVL can be read in two ways (inline with other Pyhton io modules, like json):
#
# * `pvl.load` - This is the primary method of access to read a label from an image.
#
# * `pvl.loads` - Create a PVL object from a string.  This is nice if you are going to use the `with open()` syntax to manually parse out a subset of the label or you want to generate a custom label using Python and validate it via the PVL library.
#
# The following example extracts the PVL header from a Kaguya Spectral Profiler (.spc) file. This is an 'image' file, in the sense that the header is preceeded by binary observation data.

# %%
label = pvl.load('data/SP_2C_02_07441_S136_E3584.spc')

# %% [markdown]
# The label is a PVL label object, that also acts as a Python dictionary.  Therefore, access is possible via keys.

# %%
label
# Out:
# Label([
#   (u'PDS_VERSION_ID', u'PDS3')
#   (u'RECORD_TYPE', u'UNDEFINED')
#   (u'FILE_NAME', u'SP_2C_02_07441_S136_E3584.spc')
#   (u'PRODUCT_ID', u'SP_2C_02_07441_S136_E3584')
#   (u'DATA_FORMAT', u'PDS')
#   (u'^ANCILLARY_AND_SUPPLEMENT_DATA', Units(value=24746, units=u'BYTES'))
#   (u'^SP_SPECTRUM_WAV', Units(value=38524, units=u'BYTES'))
#   (u'^SP_SPECTRUM_RAW', Units(value=39116, units=u'BYTES'))
#   (u'^SP_SPECTRUM_REF2', Units(value=88252, units=u'BYTES'))
#   (u'^SP_SPECTRUM_RAD', Units(value=137388, units=u'BYTES'))
#   (u'^SP_SPECTRUM_REF1', Units(value=186524, units=u'BYTES'))
#   (u'^SP_SPECTRUM_QA', Units(value=235660, units=u'BYTES'))
#   (u'^L2D_RESULT_ARRAY', Units(value=284796, units=u'BYTES'))
#   (u'SOFTWARE_NAME', u'RGC_SP')
#   (u'SOFTWARE_VERSION', u'2.10.3')
#   (u'PROCESS_VERSION_ID', u'L2C')
#   (u'PRODUCT_CREATION_TIME',
#    datetime.datetime(2012, 4, 21, 4, 29, 37, tzinfo=<UTC>))
#   (u'PROGRAM_START_TIME',
#    datetime.datetime(2012, 4, 21, 4, 26, 11, tzinfo=<UTC>))
#   (u'PRODUCER_ID', u'LISM')
#   (u'PRODUCT_SET_ID', u'SP_Level2C')
#   (u'PRODUCT_VERSION_ID', u'02')
#   (u'REGISTERED_PRODUCT', u'Y')
#   (u'LEVEL2B1_FILE_NAME', u'SP_2B1_02_07441_1AN0E35867N.spc')
#   (u'SOURCE_FILE_NAME', u'SP_2B2_02_07441_S136_E3584.spc')
#   (u'SPICE_METAKERNEL_FILE_NAME',
#    u'RGC_INF_TCv401IK_MIv200IK_SPv105IK_RISE100h_02_LongCK_D_V02_de421_110706.mk')
#   (u'MISSION_NAME', u'SELENE')
#   (u'SPACECRAFT_NAME', u'SELENE-M')
#   (u'DATA_SET_ID', u'SELENE_Moon_SP_Level2C')
#   (u'INSTRUMENT_NAME', u'Spectral Profiler')
#   (u'INSTRUMENT_ID', u'SP')
#   (u'MISSION_PHASE_NAME', u'Extended')
#   (u'REVOLUTION_NUMBER', 7441)
#   (u'STRIP_SEQUENCE_NUMBER', 1)
#   (u'SCENE_SEQUENCE_NUMBER', 77)
#   (u'REV_STRIP_SCENE', u'N/A')
#   (u'TARGET_NAME', u'MOON')
#   (u'OBSERVATION_MODE_ID', u'OBS-NORMAL')
#   (u'SENSOR_DESCRIPTION',
#    u'SP is a nadir-looking spectrometer which has a reflective telescope, two plane gratings, and three 128-element detectors covering 296 bands in 500 - 2600 nm. The first detector is Si PIN photodiode, and the rest are InGaAs.')
#   (u'SENSOR_DESCRIPTION2', u'SP SENSOR DESCRIPTION2')
#   (u'EXPOSURE_MODE_ID', u'SHORT')
#   (u'SHORT_EXPOSURE_DURATION', Units(value=26.0, units=u'msec'))
#   (u'LONG_EXPOSURE_DURATION', Units(value=77.0, units=u'msec'))
#   (u'CALIBRATION_MODE_ID', u'NONE')
#   (u'SPACECRAFT_CLOCK_START_COUNT', Units(value=928050128.0562, units=u'sec'))
#   (u'SPACECRAFT_CLOCK_STOP_COUNT', Units(value=928050157.9039, units=u'sec'))
#   (u'START_TIME', datetime.datetime(2009, 6, 3, 7, 42, 22, 313839, tzinfo=<UTC>))
#   (u'STOP_TIME', datetime.datetime(2009, 6, 3, 7, 42, 52, 161620, tzinfo=<UTC>))
#   (u'UPPER_LEFT_LATITUDE', Units(value=-12.835133, units=u'deg'))
#   (u'UPPER_LEFT_LONGITUDE', Units(value=358.413872, units=u'deg'))
#   (u'UPPER_RIGHT_LATITUDE', Units(value=-12.835133, units=u'deg'))
#   (u'UPPER_RIGHT_LONGITUDE', Units(value=358.413872, units=u'deg'))
#   (u'LOWER_LEFT_LATITUDE', Units(value=-14.382338, units=u'deg'))
#   (u'LOWER_LEFT_LONGITUDE', Units(value=358.382241, units=u'deg'))
#   (u'LOWER_RIGHT_LATITUDE', Units(value=-14.382338, units=u'deg'))
#   (u'LOWER_RIGHT_LONGITUDE', Units(value=358.382241, units=u'deg'))
#   (u'LOCATION_FLAG', u'D')
#   (u'ROLL_CANT', u'NO')
#   (u'MOON_SUN_DISTANCE', Units(value=151988949, units=u'km'))
#   (u'VIS_FOCAL_PLANE_TEMPERATURE', Units(value=20.35, units=u'degC'))
#   (u'N1_FOCAL_PLANE_TEMPERATURE', Units(value=17.56, units=u'degC'))
#   (u'N2_FOCAL_PLANE_TEMPERATURE', Units(value=243.0, units=u'K'))
#   (u'SATELLITE_MOVING_DIRECTION', u'+1')
#   (u'A_AXIS_RADIUS', Units(value=1737.4, units=u'km'))
#   (u'B_AXIS_RADIUS', Units(value=1737.4, units=u'km'))
#   (u'C_AXIS_RADIUS', Units(value=1737.4, units=u'km'))
#   (u'SPACECRAFT_ALTITUDE', Units(value=65.814, units=u'km'))
#   (u'SPACECRAFT_GROUND_SPEED', Units(value=1.579, units=u'km/sec'))
#   (u'VIS_BAND_NUMBER', 84)
#   (u'VIS_SPECTRAL_COVERAGE', Units(value=[482.6, 980.6], units=u'nm'))
#   (u'VIS_BAND_WIDTH', Units(value=6.0, units=u'nm'))
#   (u'N1_BAND_NUMBER', 100)
#   (u'N1_SPECTRAL_COVERAGE', Units(value=[894.4, 1688.9], units=u'nm'))
#   (u'N1_BAND_WIDTH', Units(value=8.0, units=u'nm'))
#   (u'N2_BAND_NUMBER', 112)
#   (u'N2_SPECTRAL_COVERAGE', Units(value=[1694.9, 2583.1], units=u'nm'))
#   (u'N2_BAND_WIDTH', Units(value=8.0, units=u'nm'))
#   (u'PROCESS_PARAMETER_FILE_NAME', u'SP_higher_level_proc_param.txt')
#   (u'DAYTIME_EQUATOR_CROSSING_LON', u'N/A')
#   (u'IMAGER', u'TC1')
#   (u'TM_DATA_SET_NAME', u'TC1S2A0_02SLH07441_001_0077.sl2')
#   (u'TM_CORRECTED_START_TIME',
#    datetime.datetime(2009, 6, 3, 7, 42, 10, 746710, tzinfo=<UTC>))
#   (u'TM_CORRECTED_STOP_TIME',
#    datetime.datetime(2009, 6, 3, 7, 42, 41, 4011, tzinfo=<UTC>))
#   (u'TM_CORRECTED_SAMPLING_INTERVAL', Units(value=6.499957, units=u'msec'))
#   (u'TM_LINES', 4656)
#   (u'TM_LINE_SAMPLES', 1750)
#   (u'TM_FIRST_PIXEL_NUMBER', 1172)
#   (u'TM_LAST_PIXEL_NUMBER', 2921)
#   (u'TM_UPPER_LEFT_LATITUDE', Units(value=-12.829278, units=u'deg'))
#   (u'TM_UPPER_LEFT_LONGITUDE', Units(value=358.241138, units=u'deg'))
#   (u'TM_UPPER_RIGHT_LATITUDE', Units(value=-12.833948, units=u'deg'))
#   (u'TM_UPPER_RIGHT_LONGITUDE', Units(value=358.636554, units=u'deg'))
#   (u'TM_LOWER_LEFT_LATITUDE', Units(value=-14.397875, units=u'deg'))
#   (u'TM_LOWER_LEFT_LONGITUDE', Units(value=358.211255, units=u'deg'))
#   (u'TM_LOWER_RIGHT_LATITUDE', Units(value=-14.402867, units=u'deg'))
#   (u'TM_LOWER_RIGHT_LONGITUDE', Units(value=358.605186, units=u'deg'))
#   (u'TM_SATURATED_PIXEL_PERCENTAGE', 0)
#   (u'TM_DEAD_PIXEL_PERCENTAGE', 0)
#   (u'TM_SHADOWED_AREA_PIXEL_PERCENTAGE', 0)
#   (u'HIGH_SP_POINT_NUM', 0)
#   (u'NORMAL_SP_POINT_NUM', 83)
#   (u'UPPER_MARGIN_POINT_NUM', u'N/A')
#   (u'LOWER_MARGIN_POINT_NUM', u'N/A')
#   (u'CAL_LAMP_INFO', u'N/A')
#   (u'MATCHING_ACCURACY_INFO', u'1111')
#   (u'ANCILLARY_AND_SUPPLEMENT_DATA',
#    LabelObject([
#     (u'INTERCHANGE_FORMAT', u'BINARY')
#     (u'ROWS', 83)
#     (u'COLUMNS', 43)
#     (u'ROW_BYTES', 166)
#     (u'COLUMN',
#      LabelObject([
#       (u'NAME', u'SPACECRAFT_CLOCK_COUNT')
#       (u'DATA_TYPE', u'IEEE_REAL')
#       (u'UNIT', u'sec')
#       (u'START_BYTE', 1)
#       (u'BYTES', 8)
#     ]))
#     (u'COLUMN',
#      LabelObject([
#       (u'NAME', u'VIS_FOCAL_PLANE_TEMPERATURE')
#       (u'DATA_TYPE', u'IEEE_REAL')
#       (u'UNIT', u'degC')
#       (u'START_BYTE', 9)
#       (u'BYTES', 4)
#     ]))
#     (u'COLUMN',
#      LabelObject([
#       (u'NAME', u'NIR1_FOCAL_PLANE_TEMPERATURE')
#       (u'DATA_TYPE', u'IEEE_REAL')
#       (u'UNIT', u'degC')
#       (u'START_BYTE', 13)
#       (u'BYTES', 4)
#     ]))
#     (u'COLUMN',
#      LabelObject([
#       (u'NAME', u'NIR2_FOCAL_PLANE_TEMPERATURE')
#       (u'DATA_TYPE', u'IEEE_REAL')
#       (u'UNIT', u'K')
#       (u'START_BYTE', 17)
#       (u'BYTES', 4)
#     ]))
#     (u'COLUMN',
#      LabelObject([
#       (u'NAME', u'SPECTROMETER_TEMPERATURE_1')
#       (u'DATA_TYPE', u'IEEE_REAL')
#       (u'UNIT', u'degC')
#       (u'START_BYTE', 21)
#       (u'BYTES', 4)
#     ]))
#     (u'COLUMN',
#      LabelObject([
#       (u'NAME', u'SPECTROMETER_TEMPERATURE_2')
#       (u'DATA_TYPE', u'IEEE_REAL')
#       (u'UNIT', u'degC')
#       (u'START_BYTE', 25)
#       (u'BYTES', 4)
#     ]))
#     (u'COLUMN',
#      LabelObject([
#       (u'NAME', u'SPECTROMETER_TEMPERATURE_3')
#       (u'DATA_TYPE', u'IEEE_REAL')
#       (u'UNIT', u'degC')
#       (u'START_BYTE', 29)
#       (u'BYTES', 4)
#     ]))
#     (u'COLUMN',
#      LabelObject([
#       (u'NAME', u'SPECTROMETER_TEMPERATURE_4')
#       (u'DATA_TYPE', u'IEEE_REAL')
#       (u'UNIT', u'degC')
#       (u'START_BYTE', 33)
#       (u'BYTES', 4)
#     ]))
#     (u'COLUMN',
#      LabelObject([
#       (u'NAME', u'HALOGEN_BULB_RADIANCE')
#       (u'DATA_TYPE', u'IEEE_REAL')
#       (u'UNIT', u'V')
#       (u'START_BYTE', 37)
#       (u'BYTES', 4)
#     ]))
#     (u'COLUMN',
#      LabelObject([
#       (u'NAME', u'HALOGEN_BULB_VOLTAGE1')
#       (u'DATA_TYPE', u'IEEE_REAL')
#       (u'UNIT', u'V')
#       (u'START_BYTE', 41)
#       (u'BYTES', 4)
#     ]))
#     (u'COLUMN',
#      LabelObject([
#       (u'NAME', u'HALOGEN_BULB_VOLTAGE2')
#       (u'DATA_TYPE', u'IEEE_REAL')
#       (u'UNIT', u'V')
#       (u'START_BYTE', 45)
#       (u'BYTES', 4)
#     ]))
#     (u'COLUMN',
#      LabelObject([
#       (u'NAME', u'HALOGEN_BULB_TEMPERATURE1')
#       (u'DATA_TYPE', u'IEEE_REAL')
#       (u'UNIT', u'degC')
#       (u'START_BYTE', 49)
#       (u'BYTES', 4)
#     ]))
#     (u'COLUMN',
#      LabelObject([
#       (u'NAME', u'HALOGEN_BULB_TEMPERATURE2')
#       (u'DATA_TYPE', u'IEEE_REAL')
#       (u'UNIT', u'degC')
#       (u'START_BYTE', 53)
#       (u'BYTES', 4)
#     ]))
#     (u'COLUMN',
#      LabelObject([
#       (u'NAME', u'SPACECRAFT_ALTITUDE')
#       (u'DATA_TYPE', u'IEEE_REAL')
#       (u'UNIT', u'km')
#       (u'START_BYTE', 57)
#       (u'BYTES', 4)
#     ]))
#     (u'COLUMN',
#      LabelObject([
#       (u'NAME', u'SPACECRAFT_GROUND_SPEED')
#       (u'DATA_TYPE', u'IEEE_REAL')
#       (u'UNIT', u'km/sec')
#       (u'START_BYTE', 61)
#       (u'BYTES', 4)
#     ]))
#     (u'COLUMN',
#      LabelObject([
#       (u'NAME', u'SUB_SPACECRAFT_LATITUDE')
#       (u'DATA_TYPE', u'IEEE_REAL')
#       (u'UNIT', u'deg')
#       (u'START_BYTE', 65)
#       (u'BYTES', 8)
#     ]))
#     (u'COLUMN',
#      LabelObject([
#       (u'NAME', u'SUB_SPACECRAFT_LONGITUDE')
#       (u'DATA_TYPE', u'IEEE_REAL')
#       (u'UNIT', u'deg')
#       (u'START_BYTE', 73)
#       (u'BYTES', 8)
#     ]))
#     (u'COLUMN',
#      LabelObject([
#       (u'NAME', u'CENTER_LATITUDE')
#       (u'DATA_TYPE', u'IEEE_REAL')
#       (u'UNIT', u'deg')
#       (u'START_BYTE', 81)
#       (u'BYTES', 8)
#     ]))
#     (u'COLUMN',
#      LabelObject([
#       (u'NAME', u'CENTER_LONGITUDE')
#       (u'DATA_TYPE', u'IEEE_REAL')
#       (u'UNIT', u'deg')
#       (u'START_BYTE', 89)
#       (u'BYTES', 8)
#     ]))
#     (u'COLUMN',
#      LabelObject([
#       (u'NAME', u'EMISSION_ANGLE')
#       (u'DATA_TYPE', u'IEEE_REAL')
#       (u'UNIT', u'deg')
#       (u'START_BYTE', 97)
#       (u'BYTES', 4)
#     ]))
#     (u'COLUMN',
#      LabelObject([
#       (u'NAME', u'SPACECRAFT_AZIMUTH')
#       (u'DATA_TYPE', u'IEEE_REAL')
#       (u'UNIT', u'deg')
#       (u'START_BYTE', 101)
#       (u'BYTES', 4)
#     ]))
#     (u'COLUMN',
#      LabelObject([
#       (u'NAME', u'INCIDENCE_ANGLE')
#       (u'DATA_TYPE', u'IEEE_REAL')
#       (u'UNIT', u'deg')
#       (u'START_BYTE', 105)
#       (u'BYTES', 4)
#     ]))
#     (u'COLUMN',
#      LabelObject([
#       (u'NAME', u'SOLAR_AZIMUTH_ANGLE')
#       (u'DATA_TYPE', u'IEEE_REAL')
#       (u'UNIT', u'deg')
#       (u'START_BYTE', 109)
#       (u'BYTES', 4)
#     ]))
#     (u'COLUMN',
#      LabelObject([
#       (u'NAME', u'PHASE_ANGLE')
#       (u'DATA_TYPE', u'IEEE_REAL')
#       (u'UNIT', u'deg')
#       (u'START_BYTE', 113)
#       (u'BYTES', 4)
#     ]))
#     (u'COLUMN',
#      LabelObject([
#       (u'NAME', u'SP_TEMPERATURE')
#       (u'DATA_TYPE', u'IEEE_REAL')
#       (u'UNIT', u'degC')
#       (u'START_BYTE', 117)
#       (u'BYTES', 4)
#     ]))
#     (u'COLUMN',
#      LabelObject([
#       (u'NAME', u'SP_PELTIER_HOT_TEMPERATURE')
#       (u'DATA_TYPE', u'IEEE_REAL')
#       (u'UNIT', u'degC')
#       (u'START_BYTE', 121)
#       (u'BYTES', 4)
#     ]))
#     (u'COLUMN',
#      LabelObject([
#       (u'NAME', u'SP_N2_RADIATOR_TEMPERATURE')
#       (u'DATA_TYPE', u'IEEE_REAL')
#       (u'UNIT', u'degC')
#       (u'START_BYTE', 125)
#       (u'BYTES', 4)
#     ]))
#     (u'COLUMN',
#      LabelObject([
#       (u'NAME', u'SP_CAL_VIS_TEMPERATURE')
#       (u'DATA_TYPE', u'IEEE_REAL')
#       (u'UNIT', u'degC')
#       (u'START_BYTE', 129)
#       (u'BYTES', 4)
#     ]))
#     (u'COLUMN',
#      LabelObject([
#       (u'NAME', u'SP_CAL_NIR_TEMPERATURE')
#       (u'DATA_TYPE', u'IEEE_REAL')
#       (u'UNIT', u'degC')
#       (u'START_BYTE', 133)
#       (u'BYTES', 4)
#     ]))
#     (u'COLUMN',
#      LabelObject([
#       (u'NAME', u'DPU_TEMPERATURE')
#       (u'DATA_TYPE', u'IEEE_REAL')
#       (u'UNIT', u'degC')
#       (u'START_BYTE', 137)
#       (u'BYTES', 4)
#     ]))
#     (u'COLUMN',
#      LabelObject([
#       (u'NAME', u'SP_POWER_P5V')
#       (u'DATA_TYPE', u'IEEE_REAL')
#       (u'UNIT', u'V')
#       (u'START_BYTE', 141)
#       (u'BYTES', 4)
#     ]))
#     (u'COLUMN',
#      LabelObject([
#       (u'NAME', u'SP_POWER_M15V')
#       (u'DATA_TYPE', u'IEEE_REAL')
#       (u'UNIT', u'V')
#       (u'START_BYTE', 145)
#       (u'BYTES', 4)
#     ]))
#     (u'COLUMN',
#      LabelObject([
#       (u'NAME', u'SP_POWER_P15V')
#       (u'DATA_TYPE', u'IEEE_REAL')
#       (u'UNIT', u'V')
#       (u'START_BYTE', 149)
#       (u'BYTES', 4)
#     ]))
#     (u'COLUMN',
#      LabelObject([
#       (u'NAME', u'CALIBRATION')
#       (u'DATA_TYPE', u'MSB_INTEGER')
#       (u'UNIT', u'N/A')
#       (u'START_BYTE', 153)
#       (u'BYTES', 1)
#     ]))
#     (u'COLUMN',
#      LabelObject([
#       (u'NAME', u'SP_PELTIER')
#       (u'DATA_TYPE', u'MSB_INTEGER')
#       (u'UNIT', u'N/A')
#       (u'START_BYTE', 154)
#       (u'BYTES', 1)
#     ]))
#     (u'COLUMN',
#      LabelObject([
#       (u'NAME', u'TC_MI_STATUS')
#       (u'DATA_TYPE', u'MSB_INTEGER')
#       (u'UNIT', u'N/A')
#       (u'START_BYTE', 155)
#       (u'BYTES', 1)
#     ]))
#     (u'COLUMN',
#      LabelObject([
#       (u'NAME', u'CLOCK_COUNT_ERR_FLAG')
#       (u'DATA_TYPE', u'MSB_INTEGER')
#       (u'UNIT', u'N/A')
#       (u'START_BYTE', 156)
#       (u'BYTES', 1)
#     ]))
#     (u'COLUMN',
#      LabelObject([
#       (u'NAME', u'SPATIAL_RESOLUTION_FLAG')
#       (u'DATA_TYPE', u'MSB_UNSIGNED_INTEGER')
#       (u'UNIT', u'N/A')
#       (u'START_BYTE', 157)
#       (u'BYTES', 1)
#     ]))
#     (u'COLUMN',
#      LabelObject([
#       (u'NAME', u'GEOMETRIC_INFO_RECAL_FLAG')
#       (u'DATA_TYPE', u'MSB_UNSIGNED_INTEGER')
#       (u'UNIT', u'N/A')
#       (u'START_BYTE', 158)
#       (u'BYTES', 1)
#     ]))
#     (u'COLUMN',
#      LabelObject([
#       (u'NAME', u'SUPPORT_IMAGE_LINE_POSITION')
#       (u'DATA_TYPE', u'MSB_UNSIGNED_INTEGER')
#       (u'UNIT', u'N/A')
#       (u'START_BYTE', 159)
#       (u'BYTES', 2)
#     ]))
#     (u'COLUMN',
#      LabelObject([
#       (u'NAME', u'SUPPORT_IMAGE_COLUMN_POSITION')
#       (u'DATA_TYPE', u'MSB_UNSIGNED_INTEGER')
#       (u'UNIT', u'N/A')
#       (u'START_BYTE', 161)
#       (u'BYTES', 2)
#     ]))
#     (u'COLUMN',
#      LabelObject([
#       (u'NAME', u'THUMBNAIL_LINE_POSITION')
#       (u'DATA_TYPE', u'MSB_UNSIGNED_INTEGER')
#       (u'UNIT', u'N/A')
#       (u'START_BYTE', 163)
#       (u'BYTES', 2)
#     ]))
#     (u'COLUMN',
#      LabelObject([
#       (u'NAME', u'THUMBNAIL_COLUMN_POSITION')
#       (u'DATA_TYPE', u'MSB_UNSIGNED_INTEGER')
#       (u'UNIT', u'N/A')
#       (u'START_BYTE', 165)
#       (u'BYTES', 2)
#     ]))
#   ]))
#   (u'SP_SPECTRUM_WAV',
#    LabelObject([
#     (u'LINES', 1)
#     (u'LINE_SAMPLES', 296)
#     (u'SAMPLE_TYPE', u'MSB_UNSIGNED_INTEGER')
#     (u'SAMPLE_BITS', 16)
#     (u'IMAGE_VALUE_TYPE', u'WAVELENGTH')
#     (u'UNIT', u'nm')
#     (u'SCALING_FACTOR', 0.1)
#     (u'OFFSET', 0.0)
#   ]))
#   (u'SP_SPECTRUM_RAW',
#    LabelObject([
#     (u'LINES', 83)
#     (u'LINE_SAMPLES', 296)
#     (u'SAMPLE_TYPE', u'MSB_UNSIGNED_INTEGER')
#     (u'SAMPLE_BITS', 16)
#     (u'IMAGE_VALUE_TYPE', u'RAW_DN')
#     (u'UNIT', u'ND')
#     (u'SCALING_FACTOR', u'N/A')
#     (u'OFFSET', u'N/A')
#   ]))
#   (u'SP_SPECTRUM_REF2',
#    LabelObject([
#     (u'LINES', 83)
#     (u'LINE_SAMPLES', 296)
#     (u'SAMPLE_TYPE', u'MSB_UNSIGNED_INTEGER')
#     (u'SAMPLE_BITS', 16)
#     (u'IMAGE_VALUE_TYPE', u'REFLECTANCE')
#     (u'UNIT', u'ND')
#     (u'SCALING_FACTOR', 0.0001)
#     (u'OFFSET', 0.0)
#   ]))
#   (u'SP_SPECTRUM_RAD',
#    LabelObject([
#     (u'LINES', 83)
#     (u'LINE_SAMPLES', 296)
#     (u'SAMPLE_TYPE', u'MSB_UNSIGNED_INTEGER')
#     (u'SAMPLE_BITS', 16)
#     (u'IMAGE_VALUE_TYPE', u'RADIANCE')
#     (u'UNIT', u'W/m**2/micron/sr')
#     (u'SCALING_FACTOR', 0.01)
#     (u'OFFSET', 0.0)
#   ]))
#   (u'SP_SPECTRUM_REF1',
#    LabelObject([
#     (u'LINES', 83)
#     (u'LINE_SAMPLES', 296)
#     (u'SAMPLE_TYPE', u'MSB_UNSIGNED_INTEGER')
#     (u'SAMPLE_BITS', 16)
#     (u'IMAGE_VALUE_TYPE', u'REFLECTANCE')
#     (u'UNIT', u'ND')
#     (u'SCALING_FACTOR', 0.0001)
#     (u'OFFSET', 0.0)
#   ]))
#   (u'SP_SPECTRUM_QA',
#    LabelObject([
#     (u'LINES', 83)
#     (u'LINE_SAMPLES', 296)
#     (u'SAMPLE_TYPE', u'MSB_UNSIGNED_INTEGER')
#     (u'SAMPLE_BITS', 16)
#     (u'IMAGE_VALUE_TYPE', u'QUALITY')
#     (u'UNIT', u'N/A')
#     (u'SCALING_FACTOR', 1.0)
#     (u'OFFSET', 0.0)
#   ]))
#   (u'L2D_RESULT_ARRAY',
#    LabelObject([
#     (u'LINES', 0)
#     (u'LINE_SAMPLES', 0)
#     (u'SAMPLE_TYPE', u'N/A')
#     (u'SAMPLE_BITS', 0)
#     (u'IMAGE_VALUE_TYPE', u'N/A')
#     (u'UNIT', u'N/A')
#     (u'SCALING_FACTOR', u'N/A')
#     (u'OFFSET', u'N/A')
#   ]))
# ])

# %% [markdown]
# Here the PDS_VERSION_ID key is accessed and Python unicode object is returned.

# %%
label['PDS_VERSION_ID']
# Out:
# u'PDS3'

# %% [markdown]
# Accessing a key with associated units returns a pvl unit object.

# %%
print label['^ANCILLARY_AND_SUPPLEMENT_DATA']
print type(label['^ANCILLARY_AND_SUPPLEMENT_DATA'])
# Out:
# Units(value=24746, units=u'BYTES')
# <class 'pvl._collections.Units'>

# %% [markdown]
# The unit object has two commonly used attributes: `.value` and `.units`.  These do exactly what you might expect, return the value and the unit, respectively.

# %%
anc = label['^ANCILLARY_AND_SUPPLEMENT_DATA']
print(anc.value)
print(anc.units)
# Out:
# 24746
# BYTES

# %% [markdown]
# The '^ANCILLARY_AND_SUPPLEMENT_DATA' key returns offset information for binary reading.  The 'ANCILLARY_AND_SUPPLEMENT_DATA' key is the first nested key.  The return from accessing this key is a LabelObject.

# %%
anc = label['ANCILLARY_AND_SUPPLEMENT_DATA']
print(type(anc))
print(anc)
# Out:
# <class 'pvl._collections.LabelObject'>
# LabelObject([
#   (u'INTERCHANGE_FORMAT', u'BINARY')
#   (u'ROWS', 83)
#   (u'COLUMNS', 43)
#   (u'ROW_BYTES', 166)
#   (u'COLUMN',
#    LabelObject([
#     (u'NAME', u'SPACECRAFT_CLOCK_COUNT')
#     (u'DATA_TYPE', u'IEEE_REAL')
#     (u'UNIT', u'sec')
#     (u'START_BYTE', 1)
#     (u'BYTES', 8)
#   ]))
#   (u'COLUMN',
#    LabelObject([
#     (u'NAME', u'VIS_FOCAL_PLANE_TEMPERATURE')
#     (u'DATA_TYPE', u'IEEE_REAL')
#     (u'UNIT', u'degC')
#     (u'START_BYTE', 9)
#     (u'BYTES', 4)
#   ]))
#   (u'COLUMN',
#    LabelObject([
#     (u'NAME', u'NIR1_FOCAL_PLANE_TEMPERATURE')
#     (u'DATA_TYPE', u'IEEE_REAL')
#     (u'UNIT', u'degC')
#     (u'START_BYTE', 13)
#     (u'BYTES', 4)
#   ]))
#   (u'COLUMN',
#    LabelObject([
#     (u'NAME', u'NIR2_FOCAL_PLANE_TEMPERATURE')
#     (u'DATA_TYPE', u'IEEE_REAL')
#     (u'UNIT', u'K')
#     (u'START_BYTE', 17)
#     (u'BYTES', 4)
#   ]))
#   (u'COLUMN',
#    LabelObject([
#     (u'NAME', u'SPECTROMETER_TEMPERATURE_1')
#     (u'DATA_TYPE', u'IEEE_REAL')
#     (u'UNIT', u'degC')
#     (u'START_BYTE', 21)
#     (u'BYTES', 4)
#   ]))
#   (u'COLUMN',
#    LabelObject([
#     (u'NAME', u'SPECTROMETER_TEMPERATURE_2')
#     (u'DATA_TYPE', u'IEEE_REAL')
#     (u'UNIT', u'degC')
#     (u'START_BYTE', 25)
#     (u'BYTES', 4)
#   ]))
#   (u'COLUMN',
#    LabelObject([
#     (u'NAME', u'SPECTROMETER_TEMPERATURE_3')
#     (u'DATA_TYPE', u'IEEE_REAL')
#     (u'UNIT', u'degC')
#     (u'START_BYTE', 29)
#     (u'BYTES', 4)
#   ]))
#   (u'COLUMN',
#    LabelObject([
#     (u'NAME', u'SPECTROMETER_TEMPERATURE_4')
#     (u'DATA_TYPE', u'IEEE_REAL')
#     (u'UNIT', u'degC')
#     (u'START_BYTE', 33)
#     (u'BYTES', 4)
#   ]))
#   (u'COLUMN',
#    LabelObject([
#     (u'NAME', u'HALOGEN_BULB_RADIANCE')
#     (u'DATA_TYPE', u'IEEE_REAL')
#     (u'UNIT', u'V')
#     (u'START_BYTE', 37)
#     (u'BYTES', 4)
#   ]))
#   (u'COLUMN',
#    LabelObject([
#     (u'NAME', u'HALOGEN_BULB_VOLTAGE1')
#     (u'DATA_TYPE', u'IEEE_REAL')
#     (u'UNIT', u'V')
#     (u'START_BYTE', 41)
#     (u'BYTES', 4)
#   ]))
#   (u'COLUMN',
#    LabelObject([
#     (u'NAME', u'HALOGEN_BULB_VOLTAGE2')
#     (u'DATA_TYPE', u'IEEE_REAL')
#     (u'UNIT', u'V')
#     (u'START_BYTE', 45)
#     (u'BYTES', 4)
#   ]))
#   (u'COLUMN',
#    LabelObject([
#     (u'NAME', u'HALOGEN_BULB_TEMPERATURE1')
#     (u'DATA_TYPE', u'IEEE_REAL')
#     (u'UNIT', u'degC')
#     (u'START_BYTE', 49)
#     (u'BYTES', 4)
#   ]))
#   (u'COLUMN',
#    LabelObject([
#     (u'NAME', u'HALOGEN_BULB_TEMPERATURE2')
#     (u'DATA_TYPE', u'IEEE_REAL')
#     (u'UNIT', u'degC')
#     (u'START_BYTE', 53)
#     (u'BYTES', 4)
#   ]))
#   (u'COLUMN',
#    LabelObject([
#     (u'NAME', u'SPACECRAFT_ALTITUDE')
#     (u'DATA_TYPE', u'IEEE_REAL')
#     (u'UNIT', u'km')
#     (u'START_BYTE', 57)
#     (u'BYTES', 4)
#   ]))
#   (u'COLUMN',
#    LabelObject([
#     (u'NAME', u'SPACECRAFT_GROUND_SPEED')
#     (u'DATA_TYPE', u'IEEE_REAL')
#     (u'UNIT', u'km/sec')
#     (u'START_BYTE', 61)
#     (u'BYTES', 4)
#   ]))
#   (u'COLUMN',
#    LabelObject([
#     (u'NAME', u'SUB_SPACECRAFT_LATITUDE')
#     (u'DATA_TYPE', u'IEEE_REAL')
#     (u'UNIT', u'deg')
#     (u'START_BYTE', 65)
#     (u'BYTES', 8)
#   ]))
#   (u'COLUMN',
#    LabelObject([
#     (u'NAME', u'SUB_SPACECRAFT_LONGITUDE')
#     (u'DATA_TYPE', u'IEEE_REAL')
#     (u'UNIT', u'deg')
#     (u'START_BYTE', 73)
#     (u'BYTES', 8)
#   ]))
#   (u'COLUMN',
#    LabelObject([
#     (u'NAME', u'CENTER_LATITUDE')
#     (u'DATA_TYPE', u'IEEE_REAL')
#     (u'UNIT', u'deg')
#     (u'START_BYTE', 81)
#     (u'BYTES', 8)
#   ]))
#   (u'COLUMN',
#    LabelObject([
#     (u'NAME', u'CENTER_LONGITUDE')
#     (u'DATA_TYPE', u'IEEE_REAL')
#     (u'UNIT', u'deg')
#     (u'START_BYTE', 89)
#     (u'BYTES', 8)
#   ]))
#   (u'COLUMN',
#    LabelObject([
#     (u'NAME', u'EMISSION_ANGLE')
#     (u'DATA_TYPE', u'IEEE_REAL')
#     (u'UNIT', u'deg')
#     (u'START_BYTE', 97)
#     (u'BYTES', 4)
#   ]))
#   (u'COLUMN',
#    LabelObject([
#     (u'NAME', u'SPACECRAFT_AZIMUTH')
#     (u'DATA_TYPE', u'IEEE_REAL')
#     (u'UNIT', u'deg')
#     (u'START_BYTE', 101)
#     (u'BYTES', 4)
#   ]))
#   (u'COLUMN',
#    LabelObject([
#     (u'NAME', u'INCIDENCE_ANGLE')
#     (u'DATA_TYPE', u'IEEE_REAL')
#     (u'UNIT', u'deg')
#     (u'START_BYTE', 105)
#     (u'BYTES', 4)
#   ]))
#   (u'COLUMN',
#    LabelObject([
#     (u'NAME', u'SOLAR_AZIMUTH_ANGLE')
#     (u'DATA_TYPE', u'IEEE_REAL')
#     (u'UNIT', u'deg')
#     (u'START_BYTE', 109)
#     (u'BYTES', 4)
#   ]))
#   (u'COLUMN',
#    LabelObject([
#     (u'NAME', u'PHASE_ANGLE')
#     (u'DATA_TYPE', u'IEEE_REAL')
#     (u'UNIT', u'deg')
#     (u'START_BYTE', 113)
#     (u'BYTES', 4)
#   ]))
#   (u'COLUMN',
#    LabelObject([
#     (u'NAME', u'SP_TEMPERATURE')
#     (u'DATA_TYPE', u'IEEE_REAL')
#     (u'UNIT', u'degC')
#     (u'START_BYTE', 117)
#     (u'BYTES', 4)
#   ]))
#   (u'COLUMN',
#    LabelObject([
#     (u'NAME', u'SP_PELTIER_HOT_TEMPERATURE')
#     (u'DATA_TYPE', u'IEEE_REAL')
#     (u'UNIT', u'degC')
#     (u'START_BYTE', 121)
#     (u'BYTES', 4)
#   ]))
#   (u'COLUMN',
#    LabelObject([
#     (u'NAME', u'SP_N2_RADIATOR_TEMPERATURE')
#     (u'DATA_TYPE', u'IEEE_REAL')
#     (u'UNIT', u'degC')
#     (u'START_BYTE', 125)
#     (u'BYTES', 4)
#   ]))
#   (u'COLUMN',
#    LabelObject([
#     (u'NAME', u'SP_CAL_VIS_TEMPERATURE')
#     (u'DATA_TYPE', u'IEEE_REAL')
#     (u'UNIT', u'degC')
#     (u'START_BYTE', 129)
#     (u'BYTES', 4)
#   ]))
#   (u'COLUMN',
#    LabelObject([
#     (u'NAME', u'SP_CAL_NIR_TEMPERATURE')
#     (u'DATA_TYPE', u'IEEE_REAL')
#     (u'UNIT', u'degC')
#     (u'START_BYTE', 133)
#     (u'BYTES', 4)
#   ]))
#   (u'COLUMN',
#    LabelObject([
#     (u'NAME', u'DPU_TEMPERATURE')
#     (u'DATA_TYPE', u'IEEE_REAL')
#     (u'UNIT', u'degC')
#     (u'START_BYTE', 137)
#     (u'BYTES', 4)
#   ]))
#   (u'COLUMN',
#    LabelObject([
#     (u'NAME', u'SP_POWER_P5V')
#     (u'DATA_TYPE', u'IEEE_REAL')
#     (u'UNIT', u'V')
#     (u'START_BYTE', 141)
#     (u'BYTES', 4)
#   ]))
#   (u'COLUMN',
#    LabelObject([
#     (u'NAME', u'SP_POWER_M15V')
#     (u'DATA_TYPE', u'IEEE_REAL')
#     (u'UNIT', u'V')
#     (u'START_BYTE', 145)
#     (u'BYTES', 4)
#   ]))
#   (u'COLUMN',
#    LabelObject([
#     (u'NAME', u'SP_POWER_P15V')
#     (u'DATA_TYPE', u'IEEE_REAL')
#     (u'UNIT', u'V')
#     (u'START_BYTE', 149)
#     (u'BYTES', 4)
#   ]))
#   (u'COLUMN',
#    LabelObject([
#     (u'NAME', u'CALIBRATION')
#     (u'DATA_TYPE', u'MSB_INTEGER')
#     (u'UNIT', u'N/A')
#     (u'START_BYTE', 153)
#     (u'BYTES', 1)
#   ]))
#   (u'COLUMN',
#    LabelObject([
#     (u'NAME', u'SP_PELTIER')
#     (u'DATA_TYPE', u'MSB_INTEGER')
#     (u'UNIT', u'N/A')
#     (u'START_BYTE', 154)
#     (u'BYTES', 1)
#   ]))
#   (u'COLUMN',
#    LabelObject([
#     (u'NAME', u'TC_MI_STATUS')
#     (u'DATA_TYPE', u'MSB_INTEGER')
#     (u'UNIT', u'N/A')
#     (u'START_BYTE', 155)
#     (u'BYTES', 1)
#   ]))
#   (u'COLUMN',
#    LabelObject([
#     (u'NAME', u'CLOCK_COUNT_ERR_FLAG')
#     (u'DATA_TYPE', u'MSB_INTEGER')
#     (u'UNIT', u'N/A')
#     (u'START_BYTE', 156)
#     (u'BYTES', 1)
#   ]))
#   (u'COLUMN',
#    LabelObject([
#     (u'NAME', u'SPATIAL_RESOLUTION_FLAG')
#     (u'DATA_TYPE', u'MSB_UNSIGNED_INTEGER')
#     (u'UNIT', u'N/A')
#     (u'START_BYTE', 157)
#     (u'BYTES', 1)
#   ]))
#   (u'COLUMN',
#    LabelObject([
#     (u'NAME', u'GEOMETRIC_INFO_RECAL_FLAG')
#     (u'DATA_TYPE', u'MSB_UNSIGNED_INTEGER')
#     (u'UNIT', u'N/A')
#     (u'START_BYTE', 158)
#     (u'BYTES', 1)
#   ]))
#   (u'COLUMN',
#    LabelObject([
#     (u'NAME', u'SUPPORT_IMAGE_LINE_POSITION')
#     (u'DATA_TYPE', u'MSB_UNSIGNED_INTEGER')
#     (u'UNIT', u'N/A')
#     (u'START_BYTE', 159)
#     (u'BYTES', 2)
#   ]))
#   (u'COLUMN',
#    LabelObject([
#     (u'NAME', u'SUPPORT_IMAGE_COLUMN_POSITION')
#     (u'DATA_TYPE', u'MSB_UNSIGNED_INTEGER')
#     (u'UNIT', u'N/A')
#     (u'START_BYTE', 161)
#     (u'BYTES', 2)
#   ]))
#   (u'COLUMN',
#    LabelObject([
#     (u'NAME', u'THUMBNAIL_LINE_POSITION')
#     (u'DATA_TYPE', u'MSB_UNSIGNED_INTEGER')
#     (u'UNIT', u'N/A')
#     (u'START_BYTE', 163)
#     (u'BYTES', 2)
#   ]))
#   (u'COLUMN',
#    LabelObject([
#     (u'NAME', u'THUMBNAIL_COLUMN_POSITION')
#     (u'DATA_TYPE', u'MSB_UNSIGNED_INTEGER')
#     (u'UNIT', u'N/A')
#     (u'START_BYTE', 165)
#     (u'BYTES', 2)
#   ]))
# ])

# %% [markdown]
# It is possible to access the 'INTERCHANGE_FORMAT' key using standard nested dictionary notation.

# %%
label['ANCILLARY_AND_SUPPLEMENT_DATA']['INTERCHANGE_FORMAT']
# Out:
# u'BINARY'

# %% [markdown]
# Alternatively, the `find_in_dict` function, described above can be used.

# %%
value = find_in_dict(label, 'INTERCHANGE_FORMAT')
print(value)
# Out:
# BINARY
